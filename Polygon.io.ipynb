# %%
import requests

headers = {"Authorization":"Bearer QKDR0DyLPqbvw_wZl8_tee4kDZj_25VZ"}
url = "https://api.polygon.io"

# %% [markdown]
# # Market Data

# %%
import pandas as pd

exchanges = pd.DataFrame((requests.get(url+'/v3/reference/exchanges',
                         headers=headers).json())['results'])

exchanges.set_index('id', inplace=True)

exchanges.head()
# Out:
#         type asset_class locale                       name acronym   mic  \
# id
# 1   exchange      stocks     us         NYSE American, LLC    AMEX  XASE
# 2   exchange      stocks     us        Nasdaq OMX BX, Inc.     NaN  XBOS
# 3        TRF      stocks     us        NYSE National, Inc.     NSX  XCIS
# 4        TRF      stocks     us             FINRA NYSE TRF     NaN  FINY
# 4        TRF      stocks     us  FINRA Nasdaq TRF Carteret     NaN  FINN
#
#    operating_mic participant_id  \
# id
# 1           XNYS              A
# 2           XNAS              B
# 3           XNYS              C
# 4           XNYS              D
# 4           FINR              D
#
#                                                   url
# id
# 1          https://www.nyse.com/markets/nyse-american
# 2   https://www.nasdaq.com/solutions/nasdaq-bx-sto...
# 3          https://www.nyse.com/markets/nyse-national
# 4                               https://www.finra.org
# ...

# %%
holidays = requests.get(url+'/v1/marketstatus/upcoming',
                        headers=headers).json()
holidays
# Out:
# [{'exchange': 'NASDAQ',
#   'name': 'Labor Day',
#   'date': '2021-09-06',
#   'status': 'closed'},
#  {'exchange': 'NYSE',
#   'name': 'Labor Day',
#   'date': '2021-09-06',
#   'status': 'closed'},
#  {'exchange': 'NYSE',
#   'name': 'Thanksgiving',
#   'date': '2021-11-25',
#   'status': 'closed'},
#  {'exchange': 'NASDAQ',
#   'name': 'Thanksgiving',
#   'date': '2021-11-25',
#   'status': 'closed'},
#  {'exchange': 'NYSE',
#   'name': 'Thanksgiving',
#   'date': '2021-11-26',
#   'status': 'early-close',
#   'open': '2021-11-26T14:30:00.000Z',
#   'close': '2021-11-26T18:00:00.000Z'},
#  {'exchange': 'NASDAQ',
#   'name': 'Thanksgiving',
#   'date': '2021-11-26',
#   'status': 'early-close',
#   'open': '2021-11-26T14:30:00.000Z',
#   'close': '2021-11-26T18:00:00.000Z'},
#  {'exchange': 'NASDAQ',
#   'name': 'Christmas',
#   'date': '2021-12-24',
#   'status': 'closed'},
#  {'exchange': 'NYSE',
#   'name': 'Christmas',
#   'date': '2021-12-24',
#   'status': 'closed'}]

# %%
status = requests.get(url+'/v1/marketstatus/now',
                      headers=headers).json()
status
# Out:
# {'market': 'open',
#  'earlyHours': False,
#  'afterHours': False,
#  'serverTime': '2021-08-31T13:37:40-04:00',
#  'exchanges': {'nyse': 'open', 'nasdaq': 'open', 'otc': 'open'},
#  'currencies': {'fx': 'open', 'crypto': 'open'}}

# %% [markdown]
# # Ticker Data

# %%
tickers = requests.get(url+'/v3/reference/tickers?ticker=GOOGL',
                       headers=headers).json()
tickers
# Out:
# {'results': [{'ticker': 'GOOGL',
#    'name': 'Alphabet Inc. Class A Common Stock',
#    'market': 'stocks',
#    'locale': 'us',
#    'primary_exchange': 'XNAS',
#    'type': 'CS',
#    'active': True,
#    'currency_name': 'usd',
#    'cik': '0001652044',
#    'composite_figi': 'BBG009S39JX6',
#    'share_class_figi': 'BBG009S39JY5',
#    'last_updated_utc': '2021-08-30T00:00:00Z'}],
#  'status': 'OK',
#  'request_id': 'bc3324f77622242cebbd1797810cdccd',
#  'count': 1}

# %%
ticker_detail = requests.get(url+'/v1/meta/symbols/GOOGL/company',
                       headers=headers).json()
ticker_detail
# Out:
# {'logo': 'https://s3.polygon.io/logos/googl/logo.png',
#  'listdate': '2004-08-19',
#  'cik': '1652044',
#  'bloomberg': 'EQ0000000044666717',
#  'figi': None,
#  'lei': None,
#  'sic': 7375,
#  'country': 'usa',
#  'industry': 'Online Media',
#  'sector': 'Technology',
#  'marketcap': 744878857158,
#  'employees': 94372,
#  'phone': '+1 650 253-0000',
#  'ceo': 'Larry Page',
#  'url': 'https://www.abc.xyz',
#  'description': 'Alphabet Inc is a provider of internet content products and portals. Its suite of brands includes Search, Android, YouTube, Apps, Maps & Ads.',
#  'exchange': 'Nasdaq Global Select',
#  'name': 'Alphabet Inc.',
#  'symbol': 'GOOGL',
#  'exchangeSymbol': 'NGS',
#  'hq_address': '1600 Amphitheatre Parkway Mountain View CA, 94043',
#  'hq_state': 'CA',
#  'hq_country': 'USA',
#  'type': 'CS',
#  'updated': '11/16/2018',
#  'tags': ['Technology', 'Internet Content & Information', 'Online Media'],
#  'similar': ['MSFT',
#   'AKAM',
#   'ADBE',
#   'AAPL',
# ...

# %% [markdown]
# # Stock Data

# %%
open_close = requests.get(url+'/v1/open-close/TSLA/2021-08-30',
                          headers=headers).json()
open_close
# Out:
# {'status': 'OK',
#  'from': '2021-08-30',
#  'symbol': 'TSLA',
#  'open': 714.715,
#  'high': 731,
#  'low': 712.73,
#  'close': 730.91,
#  'volume': 18584220,
#  'afterHours': 734,
#  'preMarket': 715}

# %%
previous_OHLCV = requests.get(url+'/v2/aggs/ticker/AMZN/prev',
                              headers=headers).json()
previous_OHLCV
# Out:
# {'ticker': 'AMZN',
#  'queryCount': 1,
#  'resultsCount': 1,
#  'adjusted': True,
#  'results': [{'T': 'AMZN',
#    'v': 3190354.0,
#    'vw': 3417.0943,
#    'o': 3357.425,
#    'c': 3421.57,
#    'h': 3445,
#    'l': 3355.22,
#    't': 1630353600000,
#    'n': 191516}],
#  'status': 'OK',
#  'request_id': '98946a8d0bda40e83cf6f5aff9e5ccf0',
#  'count': 1}

# %%
aggregate = requests.get(url+'/v2/aggs/ticker/FB/range/1/day/2020-08-27/2020-08-30',
                         headers=headers).json()
aggregate
# Out:
# {'ticker': 'FB',
#  'queryCount': 2,
#  'resultsCount': 2,
#  'adjusted': True,
#  'results': [{'v': 30193509.0,
#    'vw': 296.1853,
#    'o': 300.16,
#    'c': 293.22,
#    'h': 301.23,
#    'l': 292.02,
#    't': 1598500800000,
#    'n': 360648},
#   {'v': 17171515.0,
#    'vw': 293.1995,
#    'o': 295,
#    'c': 293.66,
#    'h': 297.23,
#    'l': 290.98,
#    't': 1598587200000,
#    'n': 207778}],
#  'status': 'OK',
#  'request_id': '8a0f0cc6d38c5c0beb2ef43f6237040e',
#  'count': 2}

# %% [markdown]
# # Crypto Data

# %%
open_close = requests.get(url+'/v1/open-close/crypto/ETH/USD/2020-08-31',
                          headers=headers).json()
open_close
# Out:
# {'symbol': 'ETH-USD',
#  'isUTC': True,
#  'day': '2020-08-31T00:00:00Z',
#  'open': 429.55,
#  'close': 433.775,
#  'openTrades': [{'x': 2,
#    'p': 429.55,
#    's': 0.11,
#    'c': [1],
#    'i': '499110636',
#    't': 1598832000224},
#   {'x': 2,
#    'p': 429.65,
#    's': 0.3582,
#    'c': [2],
#    'i': '499110637',
#    't': 1598832000528},
#   {'x': 1, 'p': 428.92, 's': 3, 'c': [2], 'i': '62961965', 't': 1598832000616},
#   {'x': 2,
#    'p': 429.64913775,
#    's': 0.02,
#    'c': [2],
#    'i': '499110638',
#    't': 1598832000833},
#   {'x': 1,
#    'p': 428.75,
#    's': 0.02344082,
#    'c': [2],
#    'i': '62961966',
#    't': 1598832000962}],
#  'closingTrades': [{'x': 10,
#    'p': 433.775,
#    's': 2.8614,
#    'c': [1],
#    'i': '933147201',
#    't': 1598918397926},
#   {'x': 23, 'p': 433.98, 's': 0.08, 'c': [2], 't': 1598918397753},
#   {'x': 23, 'p': 433.98, 's': 0.03473316, 'c': [2], 't': 1598918397240},
#   {'x': 1,
#    'p': 433.89,
#    's': 0.02410222,
# ...

# %%
open_close['openTrades']
# Out:
# [{'x': 2,
#   'p': 429.55,
#   's': 0.11,
#   'c': [1],
#   'i': '499110636',
#   't': 1598832000224},
#  {'x': 2,
#   'p': 429.65,
#   's': 0.3582,
#   'c': [2],
#   'i': '499110637',
#   't': 1598832000528},
#  {'x': 1, 'p': 428.92, 's': 3, 'c': [2], 'i': '62961965', 't': 1598832000616},
#  {'x': 2,
#   'p': 429.64913775,
#   's': 0.02,
#   'c': [2],
#   'i': '499110638',
#   't': 1598832000833},
#  {'x': 1,
#   'p': 428.75,
#   's': 0.02344082,
#   'c': [2],
#   'i': '62961966',
#   't': 1598832000962}]

# %%
open_close['closingTrades']
# Out:
# [{'x': 10,
#   'p': 433.775,
#   's': 2.8614,
#   'c': [1],
#   'i': '933147201',
#   't': 1598918397926},
#  {'x': 23, 'p': 433.98, 's': 0.08, 'c': [2], 't': 1598918397753},
#  {'x': 23, 'p': 433.98, 's': 0.03473316, 'c': [2], 't': 1598918397240},
#  {'x': 1,
#   'p': 433.89,
#   's': 0.02410222,
#   'c': [1],
#   'i': '63022761',
#   't': 1598918396390},
#  {'x': 23, 'p': 433.98, 's': 0.15, 'c': [2], 't': 1598918396060}]

# %%
previous_OHLCV = requests.get(url+'/v2/aggs/ticker/X:BTCUSD/prev',
                              headers=headers).json()
previous_OHLCV
# Out:
# {'ticker': 'X:BTCUSD',
#  'queryCount': 1,
#  'resultsCount': 1,
#  'adjusted': True,
#  'results': [{'T': 'X:BTCUSD',
#    'v': 20577.046324659932,
#    'vw': 47984.398,
#    'o': 48802.58,
#    'c': 46993.71,
#    'h': 48924.66460268,
#    'l': 46855.41,
#    't': 1630367999999,
#    'n': 399061}],
#  'status': 'OK',
#  'request_id': '22d6a3da9e11de4dc2fcecc9a1d0789d',
#  'count': 1}

# %%
aggregates = requests.get(url+'/v2/aggs/ticker/X:BTCUSD/range/1/day/2020-08-28/2020-08-30',
                          headers=headers).json()
aggregates
# Out:
# {'ticker': 'X:BTCUSD',
#  'queryCount': 3,
#  'resultsCount': 3,
#  'adjusted': True,
#  'results': [{'v': 49799.590460019936,
#    'vw': 11447.435,
#    'o': 11333.13,
#    'c': 11532.6,
#    'h': 11567,
#    'l': 11277.95,
#    't': 1598572800000,
#    'n': 167528},
#   {'v': 28568.91242538818,
#    'vw': 11505.8037,
#    'o': 11544.621284,
#    'c': 11468.92,
#    'h': 11606.34239887,
#    'l': 11408.1,
#    't': 1598659200000,
#    'n': 127956},
#   {'v': 30290.233652267827,
#    'vw': 11616.3356,
#    'o': 11492,
#    'c': 11730,
#    'h': 11730,
#    'l': 11458.62,
#    't': 1598745600000,
#    'n': 129570}],
#  'status': 'OK',
#  'request_id': '38312e1b55457b26e79633cf5304e2fb',
#  'count': 3}

# %% [markdown]
# # Forex

# %%
previous_OHLCV = requests.get(url+'/v2/aggs/ticker/C:EURUSD/prev',
                              headers=headers).json()
previous_OHLCV
# Out:
# {'ticker': 'C:EURUSD',
#  'queryCount': 1,
#  'resultsCount': 1,
#  'adjusted': True,
#  'results': [{'T': 'C:EURUSD',
#    'v': 81104,
#    'vw': 1.1798,
#    'o': 1.17977,
#    'c': 1.17963,
#    'h': 1.181,
#    'l': 1.1781,
#    't': 1630367999999,
#    'n': 81104}],
#  'status': 'OK',
#  'request_id': '871459e2db5f6e37e16f15d9713b79bf',
#  'count': 1}

# %%
grouped = requests.get(url+'/v2/aggs/grouped/locale/global/market/fx/2020-08-30',
                              headers=headers).json()
grouped
# Out:
# {'queryCount': 749,
#  'resultsCount': 749,
#  'adjusted': True,
#  'results': [{'T': 'C:EURMUR',
#    'v': 2,
#    'vw': 46.0708,
#    'o': 46.3216,
#    'c': 45.82,
#    'h': 46.3216,
#    'l': 45.82,
#    't': 1598831999999,
#    'n': 2},
#   {'T': 'C:MXNJPY',
#    'v': 12624,
#    'vw': 4.847,
#    'o': 4.8275,
#    'c': 4.8498,
#    'h': 4.8601,
#    'l': 4.814,
#    't': 1598831999999,
#    'n': 12624},
#   {'T': 'C:THBUSD',
#    'v': 263,
#    'vw': 0.0322,
#    'o': 0.03207,
#    'c': 0.03223,
#    'h': 0.03223,
#    'l': 0.03204,
#    't': 1598831999999,
#    'n': 263},
#   {'T': 'C:KWDEUR',
#    'v': 2,
#    'vw': 2.7063,
#    'o': 2.67023,
#    'c': 2.74228,
#    'h': 2.74228,
#    'l': 2.67023,
#    't': 1598831999999,
#    'n': 2},
#   {'T': 'C:PLNDKK',
#    'v': 5116,
#    'vw': 1.6955,
#    'o': 1.6927,
#    'c': 1.696,
#    'h': 1.6968,
#    'l': 1.6924,
#    't': 1598831999999,
#    'n': 5116},
#   {'T': 'C:MOPUSD',
#    'v': 1,
#    'vw': 0.1227,
#    'o': 0.12272,
# ...

# %%
aggregates = requests.get(url+'/v2/aggs/ticker/C:GBPUSD/range/1/day/2020-08-28/2020-08-30',
                          headers=headers).json()
aggregates
# Out:
# {'ticker': 'C:GBPUSD',
#  'queryCount': 2,
#  'resultsCount': 2,
#  'adjusted': True,
#  'results': [{'v': 341477,
#    'vw': 1.3295,
#    'o': 1.32476,
#    'c': 1.33479,
#    'h': 1.33566,
#    'l': 1.32384,
#    't': 1598572800000,
#    'n': 341477},
#   {'v': 54793,
#    'vw': 1.3349,
#    'o': 1.3333,
#    'c': 1.33558,
#    'h': 1.33694,
#    'l': 1.33325,
#    't': 1598745600000,
#    'n': 54793}],
#  'status': 'OK',
#  'request_id': 'f0e7772dea1d9f58ac8fa48a8b2920ea',
#  'count': 2}
